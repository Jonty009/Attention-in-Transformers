# %% [markdown]
# 3 components of Agents:-
#
# Routers- main planner/brain. It can be a LLM, code based, NLP classifier
# Skills- chain of individual logic blocks that does a specific task
# Memory and state- shared state that can be accessed by each component of the agent
#         Used to store:-
#         1. Retreived context
#         2. config vars
#         3. previous agent execution steps
