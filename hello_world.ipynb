# %% [markdown]
# # Hello

# %%
3*6
# Out:
# 18

# %%
3*56
# Out:
# 168

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
"Not sure what's getting uploaded"
# Out:
# "Not sure what's getting uploaded"
